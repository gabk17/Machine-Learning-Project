# %%
model_code = 'parameters {real y;} model {y ~ normal(0,1);}'
model = pystan.StanModel(model_code=model_code)  # this will take a minute
y = model.sampling(n_jobs=1).extract()['y']
y.mean()  # should be close to 0
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_5944b02c79788fa0db5b3a93728ca2bf NOW.
# -0.04672731804685985

# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\users\gabka\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: Cython>=0.22 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (0.29.24)
# Requirement already satisfied: cmdstanpy==0.9.68 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (0.9.68)
# Requirement already satisfied: pystan~=2.19.1.1 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (2.19.1.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (1.20.3)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (1.3.4)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (3.4.3)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (2.3.2)
# Requirement already satisfied: holidays>=0.10.2 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (0.12)
# Requirement already satisfied: setuptools-git>=1.2 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (1.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\gabka\anaconda3\lib\site-packages (from prophet) (4.62.3)
# Requirement already satisfied: ujson in c:\users\gabka\anaconda3\lib\site-packages (from cmdstanpy==0.9.68->prophet) (4.0.2)
# Requirement already satisfied: pytz>=2014.10 in c:\users\gabka\anaconda3\lib\site-packages (from convertdate>=2.1.2->prophet) (2021.3)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\gabka\anaconda3\lib\site-packages (from convertdate>=2.1.2->prophet) (0.5.11)
# Requirement already satisfied: hijri-converter in c:\users\gabka\anaconda3\lib\site-packages (from holidays>=0.10.2->prophet) (2.2.2)
# Requirement already satisfied: korean-lunar-calendar in c:\users\gabka\anaconda3\lib\site-packages (from holidays>=0.10.2->prophet) (0.2.1)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\gabka\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\gabka\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gabka\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gabka\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gabka\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: six in c:\users\gabka\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.0.0->prophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\gabka\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from prophet import Prophet
import pandas as pd
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')

# %%
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.213978    7.502367    8.928805
# 3266 2017-01-16  8.539051    7.816437    9.266357
# 3267 2017-01-17  8.326490    7.604435    9.028392
# 3268 2017-01-18  8.159151    7.462019    8.876484
# 3269 2017-01-19  8.171109    7.460387    8.921333

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)
